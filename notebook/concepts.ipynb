# %%
import pandas as pd

from consts import REPO_ROOT

# %%
concepts = pd.read_csv(REPO_ROOT / "data/raw/concepts.csv")
with pd.option_context("display.max_rows", None):
    display(concepts)
# Out:
#       Id                                        Name  \
# 0      1                                  Properties
# 1      2                                      Format
# 2      3                                        Time
# 3      4                                    Discrete
# 4      5                                    Realtime
# 5      6                                       Turns
# 6      7                                 Alternating
# 7      8                                Simultaneous
# 8      9                                  Stochastic
# 9     10                           HiddenInformation
# 10    11                                       Match
# 11    12                                  Asymmetric
# 12    13                             AsymmetricRules
# 13    14                         AsymmetricPlayRules
# 14    15                          AsymmetricEndRules
# 15    16                            AsymmetricForces
# 16    17                             AsymmetricSetup
# ...
